# %%
#Libraries
using Gen
using PyPlot
using Distributions
using LinearAlgebra
using Flux
using Test
using BenchmarkTools;
# Out:
# ┌ Warning: `haskey(::TargetIterator, name::String)` is deprecated, use `Target(; name = name) !== nothing` instead.
# │   caller = llvm_compat(::VersionNumber) at compatibility.jl:176
# └ @ CUDAnative C:\Users\jbere\.julia\packages\CUDAnative\ierw8\src\compatibility.jl:176

# %%
#Hyperparameters
n = 50 #50
N = 8 * n #200
σₐ = 0.00125
k_range = 4
k_real = 4
#k_list = [2,12,22,32,42,52] Novemeber 2 - first success
k_list = [2,4,6,8] #November 3 #Try a higher threshold
k_list_lite = [i for i in 1:k_range];

#Helper Functions
mₖ(k) = k*4 + 1; #Total parameter size of the net

function unpack(Θ,k)
    m = length(Θ)
    h = 2*k
    Wₕ = reshape(Θ[1:h], k, 2);   
    bₕ = reshape(Θ[h+1:h+k], k)
    #bₕ = reshape(zeros(k), k)
    
    Wₒ = reshape(Θ[h+k+1:m-1], 1, k);
    bₒ = Θ[m]
    #bₒ = 0.0
      
    return Wₕ, bₕ, Wₒ, bₒ
end

function data_labeller(y::Array{Float64})
    labels = [y[i] > 0.5 ? 2 : 1 for i=1:length(y)]
    return labels
end

function plot_data(data,classes,alpha=1.0)
    markers = ["o","*"]
    colors = ["blue","green"]
    for i=1:2
        mask = [classes[j] == i for j in 1:length(classes)]
        scatter(data[:,1][mask],data[:,2][mask],c=colors[i],alpha=alpha,marker=markers[i],zorder=3)
    end
end;

# %%
#Flexible Separable Data Generator

x_raw = rand(Uniform(-100,100),(N,2))

function linear_plot(x, slope)
    return x.*slope
end

function labeller(x,k=2)
    y = [0 for i=1:length(x[:,1])]
    slopes = [((i-1)/k)/((k-1)/k) for i=1:k]
    print(slopes)
    for i=1:length(y)
        y[i] = 1
    end
    x_line = [i/100 for i=1:100]
    for i=1:k
        y_line = linear_plot(x_line,slopes[i])
        plt.plot(x_line,y_line)
    end
end

#labeller(x_raw,4)
# Out:
# labeller (generic function with 2 methods)

# %%
#Fixed Separable Data - Multi-XOR Data
function real_data(N::Int, modes::Int, σ::Float64)
    μ₁ = [0.25, 0.25]
    μ₂ = [0.5, 0.125]
    μ₃ = [0.25, 0.75]
    μ₄ = [0.125, 0.50]
    μ₅ = [0.75, 0.75]
    μ₆ = [0.50, 0.875]
    μ₇ = [0.75, 0.25]
    μ₈ = [0.875, 0.50]
    μ = [μ₁, μ₂, μ₃, μ₄, μ₅, μ₆, μ₇, μ₈]
    Σ = [[σ, 0] [0, σ]]
    
    all_samples = zeros(Float64, (N*modes, 2))
    classes = zeros(Int, (N*modes))
    
    for i = 1:modes
        dist = MvNormal(μ[i], Σ)
        sample = rand(dist, N)::Matrix
        #scatter(sample[1,:],sample[2,:])
        all_samples[(i-1)*N+1:i*N,:] = transpose(sample)
        classes[(i-1)*N+1:i*N] = fill(i, N)
        classes = float(classes)
    end
    return all_samples, classes
end
    
data_raw, classes = real_data(Int(N/8), 8, σₐ);
classes = [(i+1) % 2 + 1 for i in classes]

plot_data(data_raw,classes)
data = transpose(data_raw)
size(data);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Bayesian Neural Net
function G(x, Θ::AbstractVector, k::Int)
    if(typeof(x) == Float64)
        x = [x]
    end
    W₁, b₁, W₂, b₂ = unpack(Θ,k)
    nn = Chain(Dense(W₁, b₁, relu),
               Dense(W₂, [b₂]))
    return nn(x)
end;

@dist k_count(r,p,min) = neg_binom(r,p) + 1

#@dist k_categorical(k_list) = k_list[categorical([1/length(k_list) for i=1:length(k_list)])]

@gen function classifier(x::Array{Float64})
    σₖ = 100.0::Float64
    
    k ~ categorical([1/length(k_list) for i=1:length(k_list)])
    k_real = k_list[k]
    #k = k_list[k]
    #print(k_real)
    #k ~ uniform_discrete(1,k_range) #Number of hidden nodes
    #k ~ k_count(1,0.5,1) #Shifted Negative Binomial
    #println(k)
    
    # Create the weight and bias vector.
    m = mₖ(k_real)
    μ = ones(m).*0
    Σ = Diagonal([σₖ for i=1:m])
    Θ ~ mvnormal(μ,Σ) #Coefficients of the polynomial
    
    #Return Network Scores for X
    scores = Flux.σ.(G(x,Θ,k_real))
    
    #Logistic Regression Likelihood
    y = @trace(mvnormal(vec(scores), Diagonal([0.0001 for i=1:length(x[1,:])])), (:y))

    return scores
    
end;

predictions = classifier(data)
preds = data_labeller(predictions)
plot_data(data_raw,preds)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Register Observed Data - Bernoulli
obs_master = choicemap()::ChoiceMap
obs_master[:y] = classes .- 1
obs = obs_master;

# %%
#Plot of Log Likelihood Scores
scores = []
accs = []
ks = []
(best_trace,) = generate(classifier, (data,), obs)
best_score = get_score(best_trace)/length(classes)
best_Θ = best_trace[:Θ]
best_k = best_trace[:k]

best_pred_y = G(data,best_Θ,k_list[best_k])
best_pred_labels = data_labeller(best_pred_y)
best_acc = sum([best_trace[:y][i] == best_pred_labels[i] for i=1:length(classes)])/length(classes)

function likelihood(best_acc)
    (trace,) = generate(classifier, (data,), obs)
    
    Θ = trace[:Θ]
    k = trace[:k]
    pred_y = G(data,Θ,k_list[k])
    pred_labels = data_labeller(pred_y)

    acc = sum([classes[i] == pred_labels[i] for i=1:length(classes)])
    score = get_score(trace)/length(classes)
    if acc > best_acc
        best_score = score
        best_trace = trace
        best_acc = acc
        best_pred_labels = pred_labels
    end
    push!(scores,score)
    push!(accs,acc)
    push!(ks, k)
end

for i=1:20000
    likelihood(best_acc)
end

scatter(accs,scores)
plt.title("Comparing Classifier Accuracy to Log Likelihood")
plt.xlabel("Classifier Accuracy")
plt.ylabel("Log Likelihood");
print(best_k)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2

# %%
#Plot of Log Likelihood Scores
chains = 8
iters = 2500

function likelihood()
    scores = []
    accs = []
    ks = []
    (best_trace,) = generate(classifier, (data,), obs)
    best_score = get_score(best_trace)/length(classes)
    best_Θ = best_trace[:Θ]
    best_k = best_trace[:k]

    best_pred_y = G(data,best_Θ,k_list[best_k])
    best_pred_labels = data_labeller(best_pred_y)
    best_acc = sum([best_trace[:y][i] == best_pred_labels[i] for i=1:length(classes)])/length(classes)
    
    for i=1:iters
        (trace,) = generate(classifier, (data,), obs)

        Θ = trace[:Θ]
        k = trace[:k]
        pred_y = G(data,Θ,k_list[k])
        pred_labels = data_labeller(pred_y)

        acc = sum([classes[i] == pred_labels[i] for i=1:length(classes)])
        score = get_score(trace)/length(classes)
        if acc > best_acc
            best_score = score
            best_trace = trace
            best_acc = acc
            best_pred_labels = pred_labels
        end
        push!(scores,score)
        push!(accs,acc)
        push!(ks, k)
    end
    
    return scores, accs, best_trace
end

scores = zeros(chains,iters)
accs = zeros(chains,iters)
best_traces = [best_trace for i=1:chains]

function parallel_like()
    Threads.@threads for i in 1:chains
        @inbounds (scores[i,:], accs[i,:], best_traces[i]) = likelihood()
    end
end

parallel_like()

accs = vec(accs)
scores = vec(scores)

print(size(scores))

scatter(accs,scores)
plt.title("Comparing Classifier Accuracy to Log Likelihood")
plt.xlabel("Classifier Accuracy")
plt.ylabel("Log Likelihood");
print(best_k)
# Out:
# (20000,
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# )2

# %%
traces = [[] for i=1:chains]
acc = [[] for i=1:chains]

function within_dimension(trace, iters, i)
    for j=1:iters
        (trace, accepted) = hmc(trace, select(:Θ), L=20, eps=0.04, check=false, observations=obs[i])
        #println("Within dimension: $(trace[:k])")
        push!(traces[i], trace)
        push!(acc[i], accepted)
    end
    return trace
end

function across_dimension(trace, iters, i)
    selection = select(:Θ,:k)
    
    args = get_args(trace)
    argdiffs = map((_) -> NoChange(), args)
    (new_trace, weight) = regenerate(trace, args, argdiffs, selection)
    test = true
    
    #first successful run: 100, 5, 0.05
    #second attempt: 10, 5, 0.05
    for j=1:30
        (new_trace, accepted) = hmc(new_trace, select(:Θ), L=20, eps=0.04, check=false, observations=obs[i])
        accepted && (test = false)
    end
    
    #test && println("Nothing accepted")
    
    score1 = exp(get_score(trace)/length(data))
    score2 = exp(get_score(new_trace)/length(data))
    score = score2/score1
    
    if rand(Uniform(0,1)) < score
        accepted = true
        trace = new_trace
        new_k = trace[:k]
        #println("New k accepted! Current k: $(new_k)")
        push!(acc[i],true)
    else
        #println("Sticking with the old k!")
        accepted = false
        push!(acc[i],false)
    end
    
    obs[i] = obs_master
    obs[i][:k] = trace[:k]
        
    push!(traces[i], trace)
    #push!(acc[i], accepted)
    return trace, trace[:k]
end

function rjmcmc(starting_trace, iters, i)
    trace = starting_trace
    k = obs[i][:k]
    println("Beginning RJMCMC. Starting k: $k")
    #@showprogress 1 "Sampling..." for i = 1:iters
    for j=1:iters
        #println("Iter $j")
        if j%1000 == 0
            println("Core $i Epoch $j Acceptance Prob: $(sum(acc[i])/length(acc[i]))")
        end
        
        if rand(Uniform(0,1)) > 0.95
            (trace, k) = across_dimension(trace, 1, i)
        else
            (trace) = within_dimension(trace, 1, i)
        end
    end
end;

# %%
#Parallel Run of the Sampler
chains = 8
iters = 20000 #20000 is successful

obs_master = choicemap()::ChoiceMap
obs_master[:y] = classes .- 1
obs = [obs_master for i in 1:chains]
starting_traces = [generate(classifier, (data,), obs[i])[1] for i=1:chains]

for i=1:chains
    obs[i][:k] = starting_traces[i][:k]
    #println(obs[i][:k])
end

function parallel_rjmcmc()
    Threads.@threads for i=1:chains
        #@inbounds println("Chain $i")
        #@inbounds println(obs[i][:k])
        @inbounds rjmcmc(starting_traces[i], iters, i)
    end
end

parallel_rjmcmc()
println("Finished")
# Out:
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Beginning RJMCMC. Starting k: 2
# Core 1 Epoch 1000 Acceptance Prob: 0.22522522522522523
# Core 2 Epoch 1000 Acceptance Prob: 0.4774774774774775
# Core 5 Epoch 1000 Acceptance Prob: 0.3973973973973974
# Core 6 Epoch 1000 Acceptance Prob: 0.0
# Core 8 Epoch 1000 Acceptance Prob: 0.9379379379379379
# Core 7 Epoch 1000 Acceptance Prob: 0.001001001001001001
# Core 4 Epoch 1000 Acceptance Prob: 0.934934934934935
# Core 3 Epoch 1000 Acceptance Prob: 0.25725725725725723
# Core 1 Epoch 2000 Acceptance Prob: 0.11255627813906953
# Core 2 Epoch 2000 Acceptance Prob: 0.39419709854927465
# Core 5 Epoch 2000 Acceptance Prob: 0.19859929964982492
# Core 6 Epoch 2000 Acceptance Prob: 0.0
# Core 8 Epoch 2000 Acceptance Prob: 0.7123561780890445
# Core 7 Epoch 2000 Acceptance Prob: 0.0005002501250625312
# Core 3 Epoch 2000 Acceptance Prob: 0.12856428214107055
# Core 4 Epoch 2000 Acceptance Prob: 0.4942471235617809
# Core 2 Epoch 3000 Acceptance Prob: 0.29709903301100365
# Core 1 Epoch 3000 Acceptance Prob: 0.07502500833611203
# Core 6 Epoch 3000 Acceptance Prob: 0.0
# Core 5 Epoch 3000 Acceptance Prob: 0.13237745915305102
# Core 8 Epoch 3000 Acceptance Prob: 0.4748249416472157
# Core 2 Epoch 4000 Acceptance Prob: 0.22280570142535633
# Core 7 Epoch 3000 Acceptance Prob: 0.00033344448149383126
# Core 3 Epoch 3000 Acceptance Prob: 0.08569523174391463
# Core 4 Epoch 3000 Acceptance Prob: 0.32977659219739913
# Core 1 Epoch 4000 Acceptance Prob: 0.056264066016504126
# Core 6 Epoch 4000 Acceptance Prob: 0.0
# Core 5 Epoch 4000 Acceptance Prob: 0.09927481870467617
# Core 2 Epoch 5000 Acceptance Prob: 0.1784356871374275
# Core 8 Epoch 4000 Acceptance Prob: 0.3560890222555639
# Core 3 Epoch 4000 Acceptance Prob: 0.06426606651662915
# Core 6 Epoch 5000 Acceptance Prob: 0.0
# Core 4 Epoch 4000 Acceptance Prob: 0.24731182795698925
# Core 1 Epoch 5000 Acceptance Prob: 0.04500900180036007
# Core 7 Epoch 4000 Acceptance Prob: 0.0005001250312578145
# Core 5 Epoch 5000 Acceptance Prob: 0.07941588317663532
# Core 2 Epoch 6000 Acceptance Prob: 0.14869144857476246
# Core 6 Epoch 6000 Acceptance Prob: 0.0
# Core 1 Epoch 6000 Acceptance Prob: 0.037506251041840306
# Core 3 Epoch 5000 Acceptance Prob: 0.051610322064412885
# Core 5 Epoch 6000 Acceptance Prob: 0.06617769628271379
# Core 8 Epoch 5000 Acceptance Prob: 0.28485697139427885
# Core 4 Epoch 5000 Acceptance Prob: 0.19803960792158432
# Core 7 Epoch 5000 Acceptance Prob: 0.00040008001600320064
# Core 2 Epoch 7000 Acceptance Prob: 0.12744677811115873
# Core 6 Epoch 7000 Acceptance Prob: 0.0
# Core 1 Epoch 7000 Acceptance Prob: 0.03214744963566224
# Core 5 Epoch 7000 Acceptance Prob: 0.056865266466638094
# Core 3 Epoch 6000 Acceptance Prob: 0.043173862310385065
# Core 2 Epoch 8000 Acceptance Prob: 0.1115139392424053
# Core 8 Epoch 6000 Acceptance Prob: 0.23737289548258042
# Core 4 Epoch 6000 Acceptance Prob: 0.16502750458409735
# Core 7 Epoch 6000 Acceptance Prob: 0.0003333888981496916
# Core 6 Epoch 8000 Acceptance Prob: 0.0
# Core 1 Epoch 8000 Acceptance Prob: 0.028128516064508065
# Core 5 Epoch 8000 Acceptance Prob: 0.04975621952744093
# Core 2 Epoch 9000 Acceptance Prob: 0.09912212468052006
# Core 3 Epoch 7000 Acceptance Prob: 0.03700528646949564
# Core 6 Epoch 9000 Acceptance Prob: 0.0
# Core 4 Epoch 7000 Acceptance Prob: 0.14144877839691383
# Core 8 Epoch 7000 Acceptance Prob: 0.20345763680525789
# Core 1 Epoch 9000 Acceptance Prob: 0.025002778086454052
# Core 5 Epoch 9000 Acceptance Prob: 0.044227136348483166
# Core 7 Epoch 7000 Acceptance Prob: 0.0004286326618088298
# Core 2 Epoch 10000 Acceptance Prob: 0.0892089208920892
# Core 6 Epoch 10000 Acceptance Prob: 0.0
# Core 3 Epoch 8000 Acceptance Prob: 0.032379047380922614
# Core 1 Epoch 10000 Acceptance Prob: 0.022502250225022502
# Core 5 Epoch 10000 Acceptance Prob: 0.039803980398039805
# Core 4 Epoch 8000 Acceptance Prob: 0.12376547068383548
# Core 2 Epoch 11000 Acceptance Prob: 0.08109828166196927
# Core 8 Epoch 8000 Acceptance Prob: 0.1780222527815977
# Core 7 Epoch 8000 Acceptance Prob: 0.00037504688086010754
# Core 6 Epoch 11000 Acceptance Prob: 0.0
# Core 5 Epoch 11000 Acceptance Prob: 0.036185107737067006
# Core 1 Epoch 11000 Acceptance Prob: 0.02054732248386217
# Core 3 Epoch 9000 Acceptance Prob: 0.028780975663962663
# Core 2 Epoch 12000 Acceptance Prob: 0.0743395282940245
# Core 4 Epoch 9000 Acceptance Prob: 0.11001222358039782
# Core 8 Epoch 9000 Acceptance Prob: 0.15823980442271363
# Core 6 Epoch 12000 Acceptance Prob: 0.0
# Core 7 Epoch 9000 Acceptance Prob: 0.000333370374486054
# Core 5 Epoch 12000 Acceptance Prob: 0.033169430785898825
# Core 1 Epoch 12000 Acceptance Prob: 0.018834902908575715
# Core 2 Epoch 13000 Acceptance Prob: 0.06862066312793291
# Core 3 Epoch 10000 Acceptance Prob: 0.0259025902590259
# Core 4 Epoch 10000 Acceptance Prob: 0.09900990099009901
# Core 6 Epoch 13000 Acceptance Prob: 0.0
# Core 8 Epoch 10000 Acceptance Prob: 0.1424142414241424
# Core 1 Epoch 13000 Acceptance Prob: 0.017385952765597353
# Core 5 Epoch 13000 Acceptance Prob: 0.030617739826140473
# Core 2 Epoch 14000 Acceptance Prob: 0.06371883705978998
# Core 7 Epoch 10000 Acceptance Prob: 0.00030003000300030005
# Core 6 Epoch 14000 Acceptance Prob: 0.0
# Core 3 Epoch 11000 Acceptance Prob: 0.02354759523593054
# Core 5 Epoch 14000 Acceptance Prob: 0.02843060218587042
# Core 1 Epoch 14000 Acceptance Prob: 0.01614401028644903
# Core 4 Epoch 11000 Acceptance Prob: 0.09000818256205109
# InterruptException:
#
# Stacktrace:
#  [1] try_yieldto(::typeof(Base.ensure_rescheduled), ::Base.RefValue{Task}) at .\task.jl:654
#  [2] wait at .\task.jl:710 [inlined]
#  [3] wait(::Base.GenericCondition{Base.Threads.SpinLock}) at .\condition.jl:106
#  [4] _wait(::Task) at .\task.jl:238
#  [5] wait(::Task) at .\task.jl:265
#  [6] macro expansion at .\threadingconstructs.jl:69 [inlined]
#  [7] parallel_rjmcmc() at .\In[106]:16
#  [8] top-level scope at In[106]:22
# Core 6 Epoch 15000 Acceptance Prob: 0.0
# Core 8 Epoch 11000 Acceptance Prob: 0.12946631511955634
# Core 7 Epoch 11000 Acceptance Prob: 0.00036366942449313574
# Core 2 Epoch 15000 Acceptance Prob: 0.05947063137542503
# Core 3 Epoch 12000 Acceptance Prob: 0.021585132094341195
# Core 1 Epoch 15000 Acceptance Prob: 0.01506767117807854
# Core 5 Epoch 15000 Acceptance Prob: 0.02653510234015601

# %%
for i=1:chains
    acceptance = [sum(acc[i][1:j])/j for j=1:length(acc[i])]
    plt.plot(acceptance)
end
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
#Bar Plot of k estimates
ks = [[traces[i][j][:k] for j=1:length(traces[i])] for i=1:chains]
ks = collect(Iterators.flatten(ks))

counts = [sum([k_list[ks[i]] == j for i in 1:length(ks)]) for j in k_list]
barlist=bar(k_list,counts)
for i in 1:k_range
    barlist[i].set_color([0.8,0.0,0.0])
end
barlist[3].set_color([0.0,0.8,0.1])

plt.title("Counts of Values for k from RJMCMC Trace")
plt.xlabel("k value")
plt.ylabel("Occurences");
